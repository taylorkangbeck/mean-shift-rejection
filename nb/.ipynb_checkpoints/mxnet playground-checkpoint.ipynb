# %% [markdown]
# ## Setup:
#
# `conda install -c conda-forge ipywidgets`
#
# *OR*
#
# `pip install ipywidgets`
#
# `jupyter nbextension enable --py widgetsnbextension`
#
# *AND*
#
# `conda install nb_conda_kernels`

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from importlib import reload
from mxnet_resnet import train_cifar10

# %%
from tqdm.notebook import tqdm

# %%
import matplotlib
matplotlib.use('Agg')

import argparse, time, logging

import numpy as np
import mxnet as mx

from mxnet import gluon, nd
from mxnet import autograd as ag
from mxnet.gluon import nn
from mxnet.gluon.data.vision import transforms

import gluoncv as gcv
gcv.utils.check_version('0.6.0')
from gluoncv.model_zoo import get_model
from gluoncv.utils import makedirs, TrainingHistory
from gluoncv.data import transforms as gcv_transforms

# %%
opt = argparse.Namespace()
opt.batch_size = 32
opt.num_gpus = 0
opt.model = 'cifar_resnet20_v1'
opt.num_workers = 4
opt.num_epochs = 3
opt.lr = 0.1
opt.momentum = 0.9
opt.wd = 0.0001
opt.lr_decay = 0.1
opt.lr_decay_period = 0
opt.lr_decay_epoch = '40,60'
opt.drop_rate = 0.0
opt.mode = 'hybrid'
opt.save_period = 10
opt.save_dir = 'params'
opt.resume_from = ''
opt.save_plot_dir = '.'
opt.save_on_quit = False
opt.zmg = 0.

# %%
reload(train_cifar10)
train_cifar10.main(opt)
# Out:
# INFO:root:Namespace(batch_size=32, drop_rate=0.0, lr=0.1, lr_decay=0.1, lr_decay_epoch='40,60', lr_decay_period=0, mode='hybrid', model='cifar_resnet20_v1', momentum=0.9, num_epochs=3, num_gpus=0, num_workers=4, resume_from='', save_dir='params', save_on_quit=False, save_period=10, save_plot_dir='.', wd=0.0001, zmg=0.0)
# HBox(children=(FloatProgress(value=0.0, description='Epochs', max=3.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=1562.0, style=ProgressStyle(description_wid…
# INFO:root:Interrupted!

# %%
# main
batch_size = opt.batch_size
classes = 10

num_gpus = opt.num_gpus
batch_size *= max(1, num_gpus)
context = [mx.gpu(i) for i in range(num_gpus)] if num_gpus > 0 else [mx.cpu()]
num_workers = opt.num_workers

lr_decay = opt.lr_decay
lr_decay_epoch = [int(i) for i in opt.lr_decay_epoch.split(',')] + [np.inf]

model_name = opt.model
if model_name.startswith('cifar_wideresnet'):
    kwargs = {'classes': classes,
            'drop_rate': opt.drop_rate}
else:
    kwargs = {'classes': classes}
net = get_model(model_name, **kwargs)
if opt.resume_from:
    net.load_parameters(opt.resume_from, ctx = context)
optimizer = 'nag'

save_period = opt.save_period
if opt.save_dir and save_period:
    save_dir = opt.save_dir
    makedirs(save_dir)
else:
    save_dir = ''
    save_period = 0

plot_path = opt.save_plot_dir

logging.basicConfig(level=logging.INFO)
logging.info(opt)

transform_train = transforms.Compose([
    gcv_transforms.RandomCrop(32, pad=4),
    transforms.RandomFlipLeftRight(),
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.4914, 0.4822, 0.4465], [0.2023, 0.1994, 0.2010])
])
# Out:
# INFO:root:Namespace(batch_size=32, drop_rate=0.0, lr=0.1, lr_decay=0.1, lr_decay_epoch='40,60', lr_decay_period=0, mode='hybrid', model='cifar_resnet20_v1', momentum=0.9, num_epochs=3, num_gpus=0, num_workers=4, resume_from='', save_dir='params', save_on_quit=False, save_period=10, save_plot_dir='.', wd=0.0001, zmg=0.0)

# %%
def test(ctx, val_data):
    """
    Evaluates net on test metric (Accuracy)
    :param ctx:
    :param val_data:
    :return: (name, value)
    """
    metric = mx.metric.Accuracy()
    for i, batch in enumerate(val_data):
        data = gluon.utils.split_and_load(batch[0], ctx_list=ctx, batch_axis=0)
        label = gluon.utils.split_and_load(batch[1], ctx_list=ctx, batch_axis=0)
        outputs = [net(X) for X in data]
        metric.update(label, outputs)
    return metric.get()

def zmg_norm(ctx, mean_mult=10.):
    """
    Normalize the net's conv params' gradients to maintain a channel-wise zero mean
    :param ctx: mxnet context
    :param mean_mult:
    """
    if opt.zmg > 0.:
        mean_dims = (2,3)  # per-channel mean
        param_dict = net.collect_params()
        for param_name in param_dict:
            if '_conv' and '_weight' in param_name:  # only modify grads of conv weights
                param = param_dict[param_name]
                # Only manipulate gradients in the given context
                ctx_indices = [param.list_ctx().index(c) for c in ctx]
                for i, grad in enumerate(param._grad):
                    if i in ctx_indices:
                        param_mean_grad = grad.mean(axis=mean_dims, keepdims=True,
                                                    name='param_mean_grad')  # IMPORTANT
                        param._grad[i] = grad + (grad - param_mean_grad) * mean_mult

# %%
if opt.mode == 'hybrid':
    net.hybridize()

# %%
ctx = context
epochs = opt.num_epochs
# train
if isinstance(ctx, mx.Context):
    ctx = [ctx]
net.initialize(mx.init.Xavier(), ctx=ctx)

train_data = gluon.data.DataLoader(
    gluon.data.vision.CIFAR10(train=True).transform_first(transform_train),
    batch_size=batch_size, shuffle=True, last_batch='discard', num_workers=num_workers)

val_data = gluon.data.DataLoader(
    gluon.data.vision.CIFAR10(train=False).transform_first(transform_test),
    batch_size=batch_size, shuffle=False, num_workers=num_workers)

trainer = gluon.Trainer(net.collect_params(), optimizer,
                        {'learning_rate': opt.lr, 'wd': opt.wd, 'momentum': opt.momentum})
metric = mx.metric.Accuracy()
train_metric = mx.metric.Accuracy()
loss_fn = gluon.loss.SoftmaxCrossEntropyLoss()
train_history = TrainingHistory(['training-error', 'validation-error'])

iteration = 0
lr_decay_count = 0

best_val_score = 0

for epoch in tqdm(range(epochs), desc='Epochs'):
    try:
        tic = time.time()
        train_metric.reset()
        metric.reset()
        train_loss = 0
        num_batch = len(train_data)
        alpha = 1

        if epoch == lr_decay_epoch[lr_decay_count]:
            trainer.set_learning_rate(trainer.learning_rate*lr_decay)
            lr_decay_count += 1

        for i, batch in enumerate(tqdm(train_data, desc='Batches')):
            data = gluon.utils.split_and_load(batch[0], ctx_list=ctx, batch_axis=0)
            label = gluon.utils.split_and_load(batch[1], ctx_list=ctx, batch_axis=0)

            with ag.record():
                output = [net(X) for X in data]
                loss = [loss_fn(yhat, y) for yhat, y in zip(output, label)]
            for l in loss:
                l.backward()
            # Apply gradient modifications TODO: mod grads in custom Trainer?
            zmg_norm(ctx)
            trainer.step(batch_size)
            train_loss += sum([l.sum().asscalar() for l in loss])

            train_metric.update(label, output)
            name, acc = train_metric.get()
            iteration += 1

        train_loss /= batch_size * num_batch
        name, acc = train_metric.get()
        name, val_acc = test(ctx, val_data)
        train_history.update([1-acc, 1-val_acc])
        train_history.plot(save_path='%s/%s_history.png'%(plot_path, model_name))

        if val_acc > best_val_score:
            best_val_score = val_acc
            net.save_parameters('%s/%.4f-cifar-%s-%d-best.params'%(save_dir, best_val_score, model_name, epoch))

        logging.info('[Epoch %d] train=%f val=%f loss=%f time: %f' %
            (epoch, acc, val_acc, train_loss, time.time()-tic))

        if save_period and save_dir and (epoch + 1) % save_period == 0:
            net.save_parameters('%s/cifar10-%s-%d.params'%(save_dir, model_name, epoch))
    except KeyboardInterrupt as ki:
        if opt.save_on_quit:
            logging.info(f'Interrupted, saving model at epoch {epoch}')
            net.save_parameters('%s/cifar10-%s-%d-interrupt.params' % (save_dir, model_name, epoch))
        else:
            logging.info('Interrupted!')
        break

if save_period and save_dir:
    net.save_parameters('%s/cifar10-%s-%d.params'%(save_dir, model_name, epochs-1))
# Out:
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_conv0_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_batchnorm0_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_batchnorm0_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_batchnorm0_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_batchnorm0_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_conv0_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm0_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm0_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm0_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm0_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_conv1_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm1_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm1_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm1_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm1_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_conv2_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm2_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm2_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm2_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm2_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_conv3_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm3_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm3_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm3_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm3_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_conv4_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm4_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm4_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm4_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm4_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_conv5_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm5_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm5_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm5_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage1_batchnorm5_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_conv0_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm0_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm0_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm0_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm0_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_conv1_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm1_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm1_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm1_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm1_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_conv2_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm2_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm2_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm2_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm2_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_conv3_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm3_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm3_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm3_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm3_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_conv4_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm4_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm4_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm4_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm4_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_conv5_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm5_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm5_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm5_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm5_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_conv6_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm6_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm6_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm6_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage2_batchnorm6_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_conv0_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm0_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm0_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm0_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm0_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_conv1_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm1_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm1_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm1_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm1_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_conv2_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm2_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm2_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm2_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm2_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_conv3_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm3_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm3_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm3_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm3_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_conv4_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm4_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm4_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm4_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm4_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_conv5_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm5_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm5_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm5_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm5_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_conv6_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm6_gamma' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm6_beta' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm6_running_mean' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_stage3_batchnorm6_running_var' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_dense0_weight' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# /Users/taylor/miniconda/envs/mxnet-msr/lib/python3.7/site-packages/mxnet/gluon/parameter.py:887: UserWarning: Parameter 'cifarresnetv117_dense0_bias' is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   v.initialize(None, ctx, init, force_reinit=force_reinit)
# HBox(children=(FloatProgress(value=0.0, description='Epochs', max=3.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=1562.0, style=ProgressStyle(description_wid…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-155-f1c05b926d5b> in <module>
#      49                 l.backward()
#      50             # Apply gradient modifications TODO: mod grads in custom Trainer?
# ---> 51             zmg_norm()
#      52             trainer.step(batch_size)
#      53             train_loss += sum([l.sum().asscalar() for l in loss])
#
# TypeError: zmg_norm() missing 1 required positional argument: 'ctx'

# %%
param_dict = net.collect_params()

# %%
[p for p in param_dict if '_conv' and '_weight' in p]
# Out:
# ['cifarresnetv117_conv0_weight',
#  'cifarresnetv117_stage1_conv0_weight',
#  'cifarresnetv117_stage1_conv1_weight',
#  'cifarresnetv117_stage1_conv2_weight',
#  'cifarresnetv117_stage1_conv3_weight',
#  'cifarresnetv117_stage1_conv4_weight',
#  'cifarresnetv117_stage1_conv5_weight',
#  'cifarresnetv117_stage2_conv0_weight',
#  'cifarresnetv117_stage2_conv1_weight',
#  'cifarresnetv117_stage2_conv2_weight',
#  'cifarresnetv117_stage2_conv3_weight',
#  'cifarresnetv117_stage2_conv4_weight',
#  'cifarresnetv117_stage2_conv5_weight',
#  'cifarresnetv117_stage2_conv6_weight',
#  'cifarresnetv117_stage3_conv0_weight',
#  'cifarresnetv117_stage3_conv1_weight',
#  'cifarresnetv117_stage3_conv2_weight',
#  'cifarresnetv117_stage3_conv3_weight',
#  'cifarresnetv117_stage3_conv4_weight',
#  'cifarresnetv117_stage3_conv5_weight',
#  'cifarresnetv117_stage3_conv6_weight',
#  'cifarresnetv117_dense0_weight']

# %%
param = param_dict['cifarresnetv117_stage1_conv0_weight']

# %%
param._grad
# Out:
# [
#  [[[[ 1.01734884e-03 -1.26682907e-01 -2.38644615e-01]
#     [ 1.14951633e-01 -5.99930733e-02 -1.72402725e-01]
#     [ 3.77090305e-01  1.33727521e-01 -5.43578453e-02]]
#
#    [[-1.60185806e-03  1.08917989e-01  2.23440737e-01]
#     [-7.09771737e-02  4.22134809e-02  1.33995742e-01]
#     [-2.05956832e-01 -6.12029657e-02  4.25772443e-02]]
#
#    [[ 1.24697760e-02 -1.27726316e-01 -2.96792269e-01]
#     [ 1.86754942e-01 -1.30796768e-02 -1.95506215e-01]
#     [ 4.65976387e-01  2.21411347e-01 -4.12230082e-02]]
#
#    ...
#
#    [[ 1.29863694e-01  9.16957855e-04 -4.00356650e-02]
#     [ 2.26372749e-01  4.86166403e-02 -3.79877388e-02]
#     [ 4.67543364e-01  2.33857989e-01  4.43990827e-02]]
#
#    [[ 7.82072395e-02  1.43067598e-01  2.00291768e-01]
#     [-5.10805324e-02  9.60586965e-02  2.03832209e-01]
#     [-3.17974895e-01 -1.36952460e-01  7.17934147e-02]]
#
#    [[-7.44201243e-04  1.24795035e-01  2.20464692e-01]
#     [-6.02310002e-02  6.69940263e-02  1.36561349e-01]
#     [-1.94393367e-01 -3.27775106e-02  5.21418452e-02]]]
#
#
#   [[[ 9.89201963e-01  7.70253390e-02 -6.90842867e-01]
#     [ 7.01204240e-01 -1.08748153e-01 -7.67694354e-01]
#     [-2.20025629e-02 -7.50868082e-01 -1.28090823e+00]]
#
#    [[-4.67404246e-01  2.49927714e-01  8.55089247e-01]
#     [-5.93611300e-01  1.09343171e-01  6.88616157e-01]
#     [-2.41868466e-01  3.90170991e-01  8.84295225e-01]]
#
#    [[ 1.28220117e+00  2.06089616e-01 -7.32604980e-01]
#     [ 1.03640020e+00  3.85543630e-02 -7.60886014e-01]
#     [ 7.62707740e-02 -7.71137595e-01 -1.41650367e+00]]
#
#    ...
#
#    [[ 1.38952720e+00  8.18700016e-01  5.49291015e-01]
#     [ 6.53483510e-01  2.48891026e-01  1.56078696e-01]
#     [-2.60359585e-01 -5.51334560e-01 -5.26731730e-01]]
#
#    [[-1.18225157e+00 -6.08672142e-01  9.46059823e-03]
#     [-1.00422591e-01  3.29302937e-01  7.63810754e-01]
#     [ 8.87715101e-01  1.26865458e+00  1.59529400e+00]]
#
#    [[-4.56211567e-01  3.05625826e-01  8.54412317e-01]
#     [-5.34801066e-01  2.03154773e-01  7.16520429e-01]
#     [-1.67055666e-01  4.91621256e-01  9.18289185e-01]]]
#
#
#   [[[ 9.16440263e-02 -1.61301002e-01 -2.94935077e-01]
#     [ 7.36939758e-02 -9.06118974e-02 -1.31691307e-01]
#     [-1.83008760e-02 -6.63978010e-02 -4.93915752e-03]]
#
#    [[-6.06903844e-02  1.48466200e-01  2.67687082e-01]
#     [-1.23352140e-01  6.94659874e-02  1.59693658e-01]
#     [-1.14435256e-01  2.43902206e-03  6.44726306e-03]]
#
#    [[ 9.22469944e-02 -2.18091607e-01 -4.24416572e-01]
#     [ 1.02862068e-01 -1.07887551e-01 -2.01282099e-01]
#     [-2.53165737e-02 -8.68015662e-02 -2.88392231e-02]]
#
#    ...
#
#    [[-1.86746746e-01 -3.07764858e-01 -2.61246741e-01]
#     [-2.02524334e-01 -1.87073588e-01  4.31375206e-03]
#     [-2.05940768e-01 -9.80732143e-02  1.43907607e-01]]
#
#    [[-3.30397606e-01 -1.76096052e-01 -5.05274087e-02]
#     [-5.55185303e-02 -3.91691737e-02 -7.11358339e-02]
#     [ 2.54441023e-01  1.85249686e-01  7.07299560e-02]]
#
#    [[-8.59892443e-02  1.47940636e-01  2.30294257e-01]
#     [-1.30962506e-01  7.81397298e-02  1.24959283e-01]
#     [-1.02673173e-01  2.21092831e-02 -1.33712552e-02]]]
#
#
#   ...
#
#
#   [[[ 9.23679411e-01 -2.94504315e-01 -1.55526602e+00]
#     [ 7.22753406e-01 -1.25921175e-01 -8.83985460e-01]
#     [ 3.66702974e-02 -4.21537697e-01 -6.35674000e-01]]
#
#    [[-5.60868561e-01  4.44116533e-01  1.55606496e+00]
#     [-7.73067474e-01  2.09345594e-01  1.13015103e+00]
#     [-7.06338584e-01 -2.95953006e-02  4.35770601e-01]]
#
#    [[ 8.98854971e-01 -5.49940526e-01 -2.15084672e+00]
#     [ 1.03362906e+00 -7.07353055e-02 -9.77411628e-01]
#     [ 1.10881850e-01 -3.48201603e-01 -5.11562347e-01]]
#
#    ...
#
#    [[ 2.86150277e-02 -5.35059333e-01 -9.26649570e-01]
#     [-9.05461162e-02  5.85048497e-02  4.17116940e-01]
#     [-8.32241058e-01 -2.57749766e-01  3.16119015e-01]]
#
#    [[-1.64772546e+00 -8.10213625e-01 -1.66472822e-01]
#     [-4.99397308e-01 -2.92999923e-01 -4.22339529e-01]
#     [ 1.54751194e+00  1.41107583e+00  1.06464362e+00]]
#
#    [[-6.79593801e-01  4.11663294e-01  1.53008628e+00]
#     [-7.82007694e-01  2.19305411e-01  1.09367335e+00]
#     [-6.01307213e-01  4.25694138e-02  4.63677704e-01]]]
#
#
#   [[[ 2.16810331e-01  1.19327046e-01  1.49505332e-01]
#     [-4.43731435e-03 -6.01694509e-02 -9.32473224e-03]
#     [-1.99574485e-01 -1.73302338e-01 -6.57011122e-02]]
#
#    [[-1.99829981e-01 -1.39078438e-01 -1.50905013e-01]
#     [-3.43324021e-02  2.25563366e-02 -1.37793487e-02]
#     [ 1.81378841e-01  2.01834142e-01  1.41912490e-01]]
#
#    [[ 3.23946655e-01  1.85430914e-01  1.99397594e-01]
#     [ 3.76067981e-02 -4.92725670e-02 -9.96085629e-03]
#     [-2.35153526e-01 -2.44165808e-01 -1.45074412e-01]]
#
#    ...
#
#    [[ 1.00724265e-01  5.31971008e-02  1.31480083e-01]
#     [-7.21150190e-02 -5.14705479e-02  3.49198431e-02]
#     [-4.95163128e-02  2.65614800e-02  1.39697641e-01]]
#
#    [[-9.95549262e-02 -4.37098742e-02 -7.50417188e-02]
#     [ 1.69596210e-01  1.36209846e-01  8.21661204e-02]
#     [ 1.98602140e-01  9.54723954e-02 -1.54777430e-02]]
#
#    [[-1.65127337e-01 -1.27501741e-01 -1.56768441e-01]
#     [ 7.76068773e-04  3.36718820e-02 -1.92499943e-02]
#     [ 1.96171775e-01  1.93912625e-01  1.18001848e-01]]]
#
#
#   [[[-1.45029902e-01  2.06801996e-01  4.28427398e-01]
#     [-1.77610725e-01  1.55399516e-01  4.51639205e-01]
#     [-7.46177137e-01 -4.73604411e-01 -1.84617341e-01]]
#
#    [[ 3.69330704e-01  1.31572336e-01 -3.89917642e-02]
#     [ 1.34724379e-01 -1.44701809e-01 -3.39611977e-01]
#     [ 3.10097218e-01  5.42105548e-02 -1.27601504e-01]]
#
#    [[-2.80603617e-01  1.53965726e-01  5.35486639e-01]
#     [-1.79328308e-01  1.89709499e-01  5.76230049e-01]
#     [-7.78041065e-01 -4.91023839e-01 -1.76974684e-01]]
#
#    ...
#
#    [[ 3.13855857e-01  6.54830337e-01  7.41031051e-01]
#     [-7.75434822e-02  1.90635413e-01  3.07344109e-01]
#     [-8.78601968e-01 -7.09494412e-01 -5.22256792e-01]]
#
#    [[-3.94228011e-01 -6.95967793e-01 -9.37730312e-01]
#     [ 1.44782856e-01 -3.72414589e-02 -2.05561355e-01]
#     [ 1.10041380e+00  1.01982129e+00  8.12427461e-01]]
#
#    [[ 3.30982953e-01  6.23878278e-02 -6.04477897e-02]
#     [ 1.32570520e-01 -1.67803645e-01 -3.21426690e-01]
#     [ 3.69286090e-01  1.00562744e-01 -6.86744899e-02]]]]
#  <NDArray 16x16x3x3 @cpu(0)>]

# %%
param.list_ctx()[0]
# Out:
# cpu(0)

# %%
param.__dict__.keys()
# Out:
# dict_keys(['_var', '_data', '_grad', '_ctx_list', '_ctx_map', '_trainer', '_deferred_init', '_differentiable', '_allow_deferred_init', '_grad_req', '_shape', 'name', '_dtype', 'lr_mult', 'wd_mult', 'init', '_grad_stype', '_stype'])

# %%
ctx_indices = [ param.list_ctx().index(c) for c in ctx ]
mean_dims = (2,3)
mean_mult = 10
for i, grad in enumerate(param._grad):
    if i in ctx_indices:
        param_mean_grad = grad.mean(axis=mean_dims, keepdims=True, name='param_mean_grad')  # IMPORTANT
        param._grad[i] = grad + (grad - param_mean_grad) * mean_mult

# %%
param._grad
# Out:
# [
#  [[[[ 1.01734884e-03 -1.26682907e-01 -2.38644615e-01]
#     [ 1.14951633e-01 -5.99930733e-02 -1.72402725e-01]
#     [ 3.77090305e-01  1.33727521e-01 -5.43578453e-02]]
#
#    [[-1.60185806e-03  1.08917989e-01  2.23440737e-01]
#     [-7.09771737e-02  4.22134809e-02  1.33995742e-01]
#     [-2.05956832e-01 -6.12029657e-02  4.25772443e-02]]
#
#    [[ 1.24697760e-02 -1.27726316e-01 -2.96792269e-01]
#     [ 1.86754942e-01 -1.30796768e-02 -1.95506215e-01]
#     [ 4.65976387e-01  2.21411347e-01 -4.12230082e-02]]
#
#    ...
#
#    [[ 1.29863694e-01  9.16957855e-04 -4.00356650e-02]
#     [ 2.26372749e-01  4.86166403e-02 -3.79877388e-02]
#     [ 4.67543364e-01  2.33857989e-01  4.43990827e-02]]
#
#    [[ 7.82072395e-02  1.43067598e-01  2.00291768e-01]
#     [-5.10805324e-02  9.60586965e-02  2.03832209e-01]
#     [-3.17974895e-01 -1.36952460e-01  7.17934147e-02]]
#
#    [[-7.44201243e-04  1.24795035e-01  2.20464692e-01]
#     [-6.02310002e-02  6.69940263e-02  1.36561349e-01]
#     [-1.94393367e-01 -3.27775106e-02  5.21418452e-02]]]
#
#
#   [[[ 9.89201963e-01  7.70253390e-02 -6.90842867e-01]
#     [ 7.01204240e-01 -1.08748153e-01 -7.67694354e-01]
#     [-2.20025629e-02 -7.50868082e-01 -1.28090823e+00]]
#
#    [[-4.67404246e-01  2.49927714e-01  8.55089247e-01]
#     [-5.93611300e-01  1.09343171e-01  6.88616157e-01]
#     [-2.41868466e-01  3.90170991e-01  8.84295225e-01]]
#
#    [[ 1.28220117e+00  2.06089616e-01 -7.32604980e-01]
#     [ 1.03640020e+00  3.85543630e-02 -7.60886014e-01]
#     [ 7.62707740e-02 -7.71137595e-01 -1.41650367e+00]]
#
#    ...
#
#    [[ 1.38952720e+00  8.18700016e-01  5.49291015e-01]
#     [ 6.53483510e-01  2.48891026e-01  1.56078696e-01]
#     [-2.60359585e-01 -5.51334560e-01 -5.26731730e-01]]
#
#    [[-1.18225157e+00 -6.08672142e-01  9.46059823e-03]
#     [-1.00422591e-01  3.29302937e-01  7.63810754e-01]
#     [ 8.87715101e-01  1.26865458e+00  1.59529400e+00]]
#
#    [[-4.56211567e-01  3.05625826e-01  8.54412317e-01]
#     [-5.34801066e-01  2.03154773e-01  7.16520429e-01]
#     [-1.67055666e-01  4.91621256e-01  9.18289185e-01]]]
#
#
#   [[[ 9.16440263e-02 -1.61301002e-01 -2.94935077e-01]
#     [ 7.36939758e-02 -9.06118974e-02 -1.31691307e-01]
#     [-1.83008760e-02 -6.63978010e-02 -4.93915752e-03]]
#
#    [[-6.06903844e-02  1.48466200e-01  2.67687082e-01]
#     [-1.23352140e-01  6.94659874e-02  1.59693658e-01]
#     [-1.14435256e-01  2.43902206e-03  6.44726306e-03]]
#
#    [[ 9.22469944e-02 -2.18091607e-01 -4.24416572e-01]
#     [ 1.02862068e-01 -1.07887551e-01 -2.01282099e-01]
#     [-2.53165737e-02 -8.68015662e-02 -2.88392231e-02]]
#
#    ...
#
#    [[-1.86746746e-01 -3.07764858e-01 -2.61246741e-01]
#     [-2.02524334e-01 -1.87073588e-01  4.31375206e-03]
#     [-2.05940768e-01 -9.80732143e-02  1.43907607e-01]]
#
#    [[-3.30397606e-01 -1.76096052e-01 -5.05274087e-02]
#     [-5.55185303e-02 -3.91691737e-02 -7.11358339e-02]
#     [ 2.54441023e-01  1.85249686e-01  7.07299560e-02]]
#
#    [[-8.59892443e-02  1.47940636e-01  2.30294257e-01]
#     [-1.30962506e-01  7.81397298e-02  1.24959283e-01]
#     [-1.02673173e-01  2.21092831e-02 -1.33712552e-02]]]
#
#
#   ...
#
#
#   [[[ 9.23679411e-01 -2.94504315e-01 -1.55526602e+00]
#     [ 7.22753406e-01 -1.25921175e-01 -8.83985460e-01]
#     [ 3.66702974e-02 -4.21537697e-01 -6.35674000e-01]]
#
#    [[-5.60868561e-01  4.44116533e-01  1.55606496e+00]
#     [-7.73067474e-01  2.09345594e-01  1.13015103e+00]
#     [-7.06338584e-01 -2.95953006e-02  4.35770601e-01]]
#
#    [[ 8.98854971e-01 -5.49940526e-01 -2.15084672e+00]
#     [ 1.03362906e+00 -7.07353055e-02 -9.77411628e-01]
#     [ 1.10881850e-01 -3.48201603e-01 -5.11562347e-01]]
#
#    ...
#
#    [[ 2.86150277e-02 -5.35059333e-01 -9.26649570e-01]
#     [-9.05461162e-02  5.85048497e-02  4.17116940e-01]
#     [-8.32241058e-01 -2.57749766e-01  3.16119015e-01]]
#
#    [[-1.64772546e+00 -8.10213625e-01 -1.66472822e-01]
#     [-4.99397308e-01 -2.92999923e-01 -4.22339529e-01]
#     [ 1.54751194e+00  1.41107583e+00  1.06464362e+00]]
#
#    [[-6.79593801e-01  4.11663294e-01  1.53008628e+00]
#     [-7.82007694e-01  2.19305411e-01  1.09367335e+00]
#     [-6.01307213e-01  4.25694138e-02  4.63677704e-01]]]
#
#
#   [[[ 2.16810331e-01  1.19327046e-01  1.49505332e-01]
#     [-4.43731435e-03 -6.01694509e-02 -9.32473224e-03]
#     [-1.99574485e-01 -1.73302338e-01 -6.57011122e-02]]
#
#    [[-1.99829981e-01 -1.39078438e-01 -1.50905013e-01]
#     [-3.43324021e-02  2.25563366e-02 -1.37793487e-02]
#     [ 1.81378841e-01  2.01834142e-01  1.41912490e-01]]
#
#    [[ 3.23946655e-01  1.85430914e-01  1.99397594e-01]
#     [ 3.76067981e-02 -4.92725670e-02 -9.96085629e-03]
#     [-2.35153526e-01 -2.44165808e-01 -1.45074412e-01]]
#
#    ...
#
#    [[ 1.00724265e-01  5.31971008e-02  1.31480083e-01]
#     [-7.21150190e-02 -5.14705479e-02  3.49198431e-02]
#     [-4.95163128e-02  2.65614800e-02  1.39697641e-01]]
#
#    [[-9.95549262e-02 -4.37098742e-02 -7.50417188e-02]
#     [ 1.69596210e-01  1.36209846e-01  8.21661204e-02]
#     [ 1.98602140e-01  9.54723954e-02 -1.54777430e-02]]
#
#    [[-1.65127337e-01 -1.27501741e-01 -1.56768441e-01]
#     [ 7.76068773e-04  3.36718820e-02 -1.92499943e-02]
#     [ 1.96171775e-01  1.93912625e-01  1.18001848e-01]]]
#
#
#   [[[-1.45029902e-01  2.06801996e-01  4.28427398e-01]
#     [-1.77610725e-01  1.55399516e-01  4.51639205e-01]
#     [-7.46177137e-01 -4.73604411e-01 -1.84617341e-01]]
#
#    [[ 3.69330704e-01  1.31572336e-01 -3.89917642e-02]
#     [ 1.34724379e-01 -1.44701809e-01 -3.39611977e-01]
#     [ 3.10097218e-01  5.42105548e-02 -1.27601504e-01]]
#
#    [[-2.80603617e-01  1.53965726e-01  5.35486639e-01]
#     [-1.79328308e-01  1.89709499e-01  5.76230049e-01]
#     [-7.78041065e-01 -4.91023839e-01 -1.76974684e-01]]
#
#    ...
#
#    [[ 3.13855857e-01  6.54830337e-01  7.41031051e-01]
#     [-7.75434822e-02  1.90635413e-01  3.07344109e-01]
#     [-8.78601968e-01 -7.09494412e-01 -5.22256792e-01]]
#
#    [[-3.94228011e-01 -6.95967793e-01 -9.37730312e-01]
#     [ 1.44782856e-01 -3.72414589e-02 -2.05561355e-01]
#     [ 1.10041380e+00  1.01982129e+00  8.12427461e-01]]
#
#    [[ 3.30982953e-01  6.23878278e-02 -6.04477897e-02]
#     [ 1.32570520e-01 -1.67803645e-01 -3.21426690e-01]
#     [ 3.69286090e-01  1.00562744e-01 -6.86744899e-02]]]]
#  <NDArray 16x16x3x3 @cpu(0)>]

# %%
param
# Out:
# Parameter cifarresnetv117_stage1_conv0_weight (shape=(16, 16, 3, 3), dtype=<class 'numpy.float32'>)
